# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
import numpy as np

# %%
import pandas as pd

# %%
#vairables
time = np.arange(0,130,10)
speeds= [9, 8, 90, 85, 80, 70, 70, 65, 55, 60, 70, 65, 50]
railgun=[75, 70, 60, 65, 60, 45, 55, 50, 40, 40, 35, 35, 30]

# %%
Speed_drop, = plt.plot(time,speeds)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
rail_drop, = plt.plot(time,railgun)

# %%
Speed_drop, = plt.plot(time,speeds, color="black",)
rail_drop, = plt.plot(time,railgun, color ="white", alpha =1)
